# %%
import pandas as pd

# %%
FWH = pd.read_csv('C:/Users/user/Desktop/Friday-WorkingHours-Morning.pcap_ISCX.csv', sep=',')

# %%
print(FWH.shape)
FWH.head()
# Out:
# (191033, 85)
#                                    Flow ID      Source IP   Source Port  \
# 0  192.168.10.3-192.168.10.50-3268-56108-6  192.168.10.50         56108
# 1   192.168.10.3-192.168.10.50-389-42144-6  192.168.10.50         42144
# 2                    8.0.6.4-8.6.0.1-0-0-0        8.6.0.1             0
# 3   192.168.10.9-224.0.0.252-63210-5355-17   192.168.10.9         63210
# 4            192.168.10.9-224.0.0.22-0-0-0   192.168.10.9             0
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.3               3268          6  7/7/2017 8:59
# 1    192.168.10.3                389          6  7/7/2017 8:59
# 2         8.0.6.4                  0          0  7/7/2017 9:00
# 3     224.0.0.252               5355         17  7/7/2017 9:00
# 4      224.0.0.22                  0          0  7/7/2017 9:00
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
FWHD=FWH.drop('Flow ID',1)

FWHD[' Source IP'][1]
# Out:
# '192.168.10.50'

# %%
import socket
import struct

for i in range(0,191033) :
    a=struct.unpack("!I", socket.inet_aton(str(FWHD[' Source IP'][i])))[0]
    FWHD.iat[i,0]=a

# %%
#3268
FWHD.head()
# Out:
#     Source IP   Source Port  Destination IP   Destination Port   Protocol  \
# 0  3232238130         56108    192.168.10.3               3268          6
# 1  3232238130         42144    192.168.10.3                389          6
# 2   134610945             0         8.0.6.4                  0          0
# 3  3232238089         63210     224.0.0.252               5355         17
# 4  3232238089             0      224.0.0.22                  0          0
#
#        Timestamp   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0  7/7/2017 8:59       112740690                  32                       16
# 1  7/7/2017 8:59       112740560                  32                       16
# 2  7/7/2017 9:00       113757377                 545                        0
# 3  7/7/2017 9:00          100126                  22                        0
# 4  7/7/2017 9:00           54760                   4                        0
#
# ...

# %%
for i in range(0,191033) :
    a=struct.unpack("!I", socket.inet_aton(str(FWHD[' Destination IP'][i])))[0]
    FWHD.iat[i,2]=a

# %%
FWHD1=FWHD.drop(' Timestamp',1)

# %%
FWHD1.head()
# Out:
#     Source IP   Source Port  Destination IP   Destination Port   Protocol  \
# 0  3232238130         56108      3232238083               3268          6
# 1  3232238130         42144      3232238083                389          6
# 2   134610945             0       134219268                  0          0
# 3  3232238089         63210      3758096636               5355         17
# 4  3232238089             0      3758096406                  0          0
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0       112740690                  32                       16
# 1       112740560                  32                       16
# 2       113757377                 545                        0
# 3          100126                  22                        0
# 4           54760                   4                        0
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  ...  \
# 0                         6448                        1152.0  ...
# ...

# %%
FWHD1.isnull().any(axis=0).sum()
# Out:
# 1

# %%
FWHD1.isna().sum()
# Out:
#  Source IP           0
#  Source Port         0
#  Destination IP      0
#  Destination Port    0
#  Protocol            0
#                     ..
# Idle Mean            0
#  Idle Std            0
#  Idle Max            0
#  Idle Min            0
#  Label               0
# Length: 83, dtype: int64

# %%
FWHD1.keys()
# Out:
# Index([' Source IP', ' Source Port', ' Destination IP', ' Destination Port',
#        ' Protocol', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
# ...

# %%
for i in range(0,191033) :
    c=FWHD1.Init_Win_bytes_forward[i]
    d=FWHD1. Init_Win_bytes_backward[i]
    if c==-1 :
        FWHD1.Init_Win_bytes_forward[i]=0
    else :
        pass
    if d==-1 :
        FWHD1. Init_Win_bytes_backward[i]=0
    else :
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-2a17f56c50bd> in <module>
#       1 for i in range(0,191033) :
#       2     c=FWHD1.Init_Win_bytes_forward[i]
# ----> 3     d=FWHD1. Init_Win_bytes_backward[i]
#       4     if c==-1 :
#       5         FWHD1.Init_Win_bytes_forward[i]=0
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Init_Win_bytes_backward'

# %%
Label1 = pd.get_dummies(FWHD1[' Label'])
print(Label1)
FWHD2 = pd.concat([FWHD1, Label1], axis=1)
# Out:
#         BENIGN  Bot
# 0            1    0
# 1            1    0
# 2            1    0
# 3            1    0
# 4            1    0
# ...        ...  ...
# 191028       1    0
# 191029       1    0
# 191030       1    0
# 191031       1    0
# 191032       1    0
#
# [191033 rows x 2 columns]

# %%
FWHD2.head()
# Out:
#     Source IP   Source Port  Destination IP   Destination Port   Protocol  \
# 0  3232238130         56108      3232238083               3268          6
# 1  3232238130         42144      3232238083                389          6
# 2   134610945             0       134219268                  0          0
# 3  3232238089         63210      3758096636               5355         17
# 4  3232238089             0      3758096406                  0          0
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0       112740690                  32                       16
# 1       112740560                  32                       16
# 2       113757377                 545                        0
# 3          100126                  22                        0
# 4           54760                   4                        0
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  ...  \
# 0                         6448                        1152.0  ...
# ...

# %%
FWHD3=FWHD2.drop(' Label',axis=1)

# %%
FWHD3.head()
# Out:
#     Source IP   Source Port  Destination IP   Destination Port   Protocol  \
# 0  3232238130         56108      3232238083               3268          6
# 1  3232238130         42144      3232238083                389          6
# 2   134610945             0       134219268                  0          0
# 3  3232238089         63210      3758096636               5355         17
# 4  3232238089             0      3758096406                  0          0
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0       112740690                  32                       16
# 1       112740560                  32                       16
# 2       113757377                 545                        0
# 3          100126                  22                        0
# 4           54760                   4                        0
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  ...  \
# 0                         6448                        1152.0  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MMS1=FWHD3.drop(' Source IP', 1)
MMS2=MMS1.drop(' Source Port', 1)
MMS3=MMS2.drop(' Destination IP', 1)
MMS4=MMS3.drop('BENIGN', 1)
MMS5=MMS4.drop('Bot',1)

MMS6=MMS5.drop(' Active Min', 1)
MMS7=MMS6.drop('Idle Mean', 1)
MMS8=MMS7.drop(' Idle Std', 1)
MMS9=MMS8.drop(' Idle Max', 1)
MMS10=MMS9.drop(' Idle Min', 1)
MMS11=MMS10.drop('Active Mean',1)
MMS12=MMS11.drop(' Active Std',1)
MMS13=MMS12.drop(' Active Max',1)

# %%
MMSE=MinMaxScaler()
MMSE.fit(MMS13)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-7f48037295bd> in <module>
#       1 MMSE=MinMaxScaler()
# ----> 2 MMSE.fit(MMS13)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     371         X = check_array(X,
#     372                         estimator=self, dtype=FLOAT_DTYPES,
# --> 373                         force_all_finite="allow-nan")
#     374
#     375         data_min = np.nanmin(X, axis=0)
#
# ...

# %%
print(MMS13.dtypes)
# Out:
#  Destination Port           int64
#  Protocol                   int64
#  Flow Duration              int64
#  Total Fwd Packets          int64
#  Total Backward Packets     int64
#                             ...
#  Subflow Bwd Bytes          int64
# Init_Win_bytes_forward      int64
#  Init_Win_bytes_backward    int64
#  act_data_pkt_fwd           int64
#  min_seg_size_forward       int64
# Length: 71, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(MMS5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3b9b42b73ee9> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 sc.fit(MMS5)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
#     671     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     698         X = check_array(X, accept_sparse=('csr', 'csc'),
#     699                         estimator=self, dtype=FLOAT_DTYPES,
# --> 700                         force_all_finite='allow-nan')
#     701
#     702         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ...

# %%
def standard (**kwargs) :
    star=list(**kwargs.keys())
    for i in star :
        **kwargs[i].sum()
# Out:
#   File "<ipython-input-35-b6938a28953a>", line 4
#     **kwargs[i].sum()
#      ^
# SyntaxError: invalid syntax

# %%
list(MMS13.keys())
MMS13[' Protocol'].sum()
# Out:
# 2197788

# %%
import os
housing_dir = os.path.join("datasets", "housing")
print(housing_dir)
# Out:
# datasets\housing

# %%
def save_to_multiple_csv_files(data, name_prefix, header=None, n_parts=10):
    housing_dir = os.path.join("datasets", "housing")
    os.makedirs(housing_dir, exist_ok=True)
    path_format = os.path.join(housing_dir, "my_{}_{:02d}.csv")

    filepaths = []
    m = len(data)
    for file_idx, row_indices in enumerate(np.array_split(np.arange(m), n_parts)):
        part_csv = path_format.format(name_prefix, file_idx)
        filepaths.append(part_csv)
        with open(part_csv, "wt", encoding="utf-8") as f:
            if header is not None:
                f.write(header)
                f.write("\n")
            for row_idx in row_indices:
                f.write(",".join([repr(col) for col in data[row_idx]]))
                f.write("\n")
    return filepaths

# %%
MMS5.head()
# Out:
#     Destination Port   Protocol   Flow Duration   Total Fwd Packets  \
# 0               3268          6       112740690                  32
# 1                389          6       112740560                  32
# 2                  0          0       113757377                 545
# 3               5355         17          100126                  22
# 4                  0          0           54760                   4
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       16                         6448
# 1                       16                         6448
# 2                        0                            0
# 3                        0                          616
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                        1152.0                     403
# 1                        5056.0                     403
# ...
