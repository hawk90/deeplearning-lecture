# %%
import tensorflow as tf
import pandas as pd
import cv2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('./ictcog_Deeplearning_full/Lecture-ipynb/datasets/ants/swiss-army-ant.jpg')
print(img.shape)
img = np.array(img)
print(img)
plt.imshow(img)
# Out:
# (261, 280, 3)
# [[[ 60   4  33]
#   [ 28   0  10]
#   [ 12   7   9]
#   ...
#   [  4   2   0]
#   [ 13   0   2]
#   [ 17   0   4]]
#
#  [[ 28   0  10]
#   [ 16   0   6]
#   [ 21  33  27]
#   ...
#   [ 15  27  15]
#   [ 19  18  14]
#   [  4   0   0]]
#
#  [[ 18  12  17]
#   [ 24  35  32]
#   [ 92 139 117]
#   ...
#   [127 165 143]
#   [ 99 124 110]
#   [ 11  33  21]]
#
#  ...
#
#  [[  0  10   0]
#   [  6  34   5]
#   [ 95 132  94]
#   ...
#   [ 45  85  57]
#   [ 33  66  39]
#   [  0  11   0]]
#
#  [[  0  14   0]
#   [  3  29   6]
#   [115 147 116]
#   ...
#   [ 39  67  47]
#   [ 39  61  42]
#   [  0  15   0]]
#
#  [[  0   1   0]
#   [  0   3   0]
#   [ 34  47  33]
#   ...
#   [ 10  19  16]
#   [ 19  19  19]
#   [  2   0   0]]]

# %%
img_bgr = cv2.resize(img,(128,128))
plt.imshow(img_rgb)

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_resized = tf.image.random_crop(img_rgb,[64,64,3])
plt.imshow(img_resized)

# %%
pad_img = tf.image.resize_with_pad(img_resized,128, 128,'gaussian')
# plt.imshow(pad_img)
#print(pad_img)
print(pad_img.shape)
pad_img = pad_img/255
plt.imshow(pad_img,'binary')

# tf.image.resize_with_pad(
#     image, target_height, target_width, method=ResizeMethod.BILINEAR,
#     antialias=False
# )
# Out:
# (128, 128, 3)

# %%
plt.subplot(131)
plt.imshow(img_rgb)
plt.subplot(132)
plt.imshow(img_resized)
plt.subplot(133)
plt.imshow(pad_img)
