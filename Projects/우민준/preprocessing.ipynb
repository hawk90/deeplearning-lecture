# %%
import os
import cv2
import numpy as np
import pickle as pk
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a= 'C:/Users/user/ANACONDA TESTFILE/datasets/cifar10-py/data_batch_{}'.format(i)

# %%
DB=[]
for i in range(1,6) :
    a= 'C:/Users/user/ANACONDA TESTFILE/datasets/cifar10-py/data_batch_{}'.format(i)
    a
    with open(a, mode='rb') as f:
        data = pk.load(f, encoding='bytes')
        DB.append(data)

# %%
len(DB)

# %%
A=DB[0]
print(A.keys())

# %%
NOlabels=[]
for i in range(5) :
    A=DB[i]
    NOlabels.append(A[b'data'])

# %%
CHECK=np.array(NOlabels)
print(CHECK.shape)

# %%
type(NOlabels)

# %%
NEEDPICTURE=CHECK.reshape(5,10000,32,32,3)
SEE=NEEDPICTURE[0][0]
PR=np.array(SEE)
PR.shape

# %%
Test = cv2.imread('C:/Users/user/ANACONDA TESTFILE/datasets/ants/001335.jpg')#실험
plt.imshow(cv2.cvtColor(Test, cv2.COLOR_BGR2RGB))
plt.show()

# %%
path = "./0013035-Copy1.jpg"

src = cv2.imread(path) 

image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV ) 
  
plt.imshow(image)

# %%
bicubic_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_CUBIC)

# %%
b='C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/test/images/test_0.jpg'

# %%
# !pip install opencv-python
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
b='C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/test/images/test_0.jpg'

for i in range(1,6) :
    a= 'C:/Users/user/ANACONDA TESTFILE/datasets/cifar10-py/data_batch_{}'.format(i)
    a
    with open(a, mode='rb') as f:
        data = pk.load(f, encoding='bytes')
        DB.append(data)
img = cv2.imread(b)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-afa3ecd0aedd> in <module>
# ----> 1 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#       2 plt.show()
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-6sxsq0tp\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
path = "C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/test/images/test_0.jpg"

src = cv2.imread(path) 

image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV ) 
  
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-6e80544dd7b1> in <module>
#       3 src = cv2.imread(path)
#       4
# ----> 5 image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV )
#       6
#       7 plt.imshow(image)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-6sxsq0tp\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
import cv2
import numpy as np
import pickle as pk
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


files = os.listdir('C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train')
path='C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train'

len(files)
files
# Out:
# ['n01443537',
#  'n01629819',
#  'n01641577',
#  'n01644900',
#  'n01698640',
#  'n01742172',
#  'n01768244',
#  'n01770393',
#  'n01774384',
#  'n01774750',
#  'n01784675',
#  'n01855672',
#  'n01882714',
#  'n01910747',
#  'n01917289',
#  'n01944390',
#  'n01945685',
#  'n01950731',
#  'n01983481',
#  'n01984695',
#  'n02002724',
#  'n02056570',
#  'n02058221',
#  'n02074367',
#  'n02085620',
#  'n02094433',
#  'n02099601',
#  'n02099712',
#  'n02106662',
#  'n02113799',
#  'n02123045',
#  'n02123394',
#  'n02124075',
#  'n02125311',
#  'n02129165',
#  'n02132136',
#  'n02165456',
#  'n02190166',
#  'n02206856',
#  'n02226429',
#  'n02231487',
#  'n02233338',
#  'n02236044',
#  'n02268443',
#  'n02279972',
#  'n02281406',
#  'n02321529',
#  'n02364673',
#  'n02395406',
#  'n02403003',
#  'n02410509',
#  'n02415577',
#  'n02423022',
#  'n02437312',
#  'n02480495',
#  'n02481823',
#  'n02486410',
#  'n02504458',
#  'n02509815',
#  'n02666196',
#  'n02669723',
#  'n02699494',
# ...

# %%
c=[]
image=[]
for i in range(0,200) :
    files_path=path+'/'+files[i]+'/images/'+files[i]+'_'
    
    for i in range(0,500) :
        file_real_path=files_path+'{}.jpeg'.format(i)
        c.append(file_real_path)
len(c)
c
# Out:
# ['C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_0.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_1.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_2.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_3.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_4.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_5.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_6.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_7.jpeg',
#  'C:/Users/user/ANACONDA TESTFILE/datasets/tiny-imagenet-200/train/n01443537/images/n01443537_8.jpeg',
# ...

# %%
path = c[0]

src = cv2.imread(path) 

image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV ) 
  
plt.imshow(image)

# %%
image
# Out:
# array([[[166, 119, 255],
#         [166, 117, 255],
#         [165, 105, 249],
#         ...,
#         [ 88,  31, 237],
#         [ 89,  34, 241],
#         [ 88,  56, 163]],
#
#        [[165, 129, 255],
#         [165, 126, 254],
#         [164, 113, 246],
#         ...,
#         [ 89,  29, 231],
#         [ 87,  35, 234],
#         [ 87,  58, 159]],
#
#        [[163, 129, 255],
#         [163, 126, 255],
#         [163, 120, 255],
#         ...,
#         [ 87,  28, 233],
#         [ 85,  35, 234],
#         [ 85,  58, 155]],
#
#        ...,
#
#        [[ 46, 107, 122],
#         [ 46, 103, 119],
#         [ 45, 101, 116],
#         ...,
#         [ 19,  87,  85],
#         [ 19,  95,  78],
#         [ 19,  79,  94]],
#
#        [[ 46, 111, 117],
#         [ 46, 106, 115],
#         [ 45, 105, 112],
#         ...,
#         [ 19,  86,  86],
#         [ 19,  96,  77],
#         [ 19,  85,  87]],
#
#        [[ 46, 109, 119],
#         [ 47, 105, 119],
#         [ 45, 101, 116],
# ...

# %%
d=[]
for f in c:
        # 이미지를 그레이 스케일로 리드
        img = cv2.imread(f,1)
        # 이미지를 리사이즈
        # 픽셀값을 보존
        img = np.array(img).flatten().tolist()
        d.append(img)
'''
    for f in files:
        # 이미지를 그레이 스케일로 리드
        img = cv2.imread('./data/' + d + '/' + f, 0)
        # 이미지를 리사이즈
        img = cv2.resize(img, (128, 128))
        # 픽셀값을 보존
        img = np.array(img).flatten().tolist()
        pixels.append(img)
        
        # 이미지의 레이블을 리스트에 보존 
        labels.append(i)
'''

# %%
d
# Out:
# [[None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
#  [None],
# ...

# %%
# Out:
# (100000, 1)

# %%
f
# Out:
# array([[None],
#        [None],
#        [None],
#        ...,
#        [None],
#        [None],
#        [None]], dtype=object)
